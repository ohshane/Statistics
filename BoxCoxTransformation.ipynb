# %%
import numpy as np
import matplotlib.pyplot as plt

# x = np.random.exponential(1, 1000)
# plt.hist(x, bins=100)
# plt.show()

x = np.random.lognormal(0, 2, 1000)
x = np.concatenate([x, np.zeros(100)])

plt.hist(x, bins=100)
plt.show()

plt.hist(np.log1p(x), bins=100)
plt.show()

plt.hist(np.log(x + 1e-7), bins=100)
plt.show()



# plt.hist(np.log1p(x), bins=100)
# plt.show()
# plt.hist(np.log(x + 1e-1), bins=100)
# plt.show()

# %%
import numpy as np
import torch

torch.tensor(1, dtype=torch.float32)
# Out:
# tensor(1., dtype=torch.float64)
